# %%
import cv2
import ollama
import time

# 2. Clean file path: Notice the 'r' at the start and only ONE set of quotes!
video_path = r"C:\beach\data\raw\beach\fighting\crazy fight breaks off at the beach ｜ #fight #worldstar #fyp #shorts #beach [LiW9YUSt3Zg].mp4"

# Open the video using OpenCV
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file. Check if the path is 100% correct.")
else:
    # Get the frame rate (FPS) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video loaded successfully. FPS: {fps}")

    frame_count = 0
    analyses_done = 0

    print("Starting video analysis. Processing 1 frame per second (Max 3 frames for this test)...")

    while cap.isOpened() and analyses_done < 3:
        ret, frame = cap.read()
        
        if not ret:
            print("End of video reached.")
            break
            
        # Process 1 frame every second
        if frame_count % int(fps) == 0:
            print(f"\n--- Analyzing video at second {analyses_done} ---")
            
            # Convert the OpenCV frame (numpy array) into JPG image bytes for LLaVA
            _, buffer = cv2.imencode('.jpg', frame)
            image_bytes = buffer.tobytes()
            
            # Send the extracted frame to LLaVA
            response = ollama.generate(
                model='llava:13b',
                prompt='You are monitoring a beach safety camera. Briefly describe the scene. Is anyone fighting?',
                images=[image_bytes]
            )
            
            print(f"LLaVA: {response['response']}")
            analyses_done += 1
            
        frame_count += 1

    # Clean up
    cap.release()
    print("\nVideo test complete!")
# Out:
# Video loaded successfully. FPS: 30.0
# Starting video analysis. Processing 1 frame per second (Max 3 frames for this test)...
#
# --- Analyzing video at second 0 ---
# LLaVA:  The image shows two individuals on a sandy beach. One person is standing and appears to be in motion, possibly dancing or moving with exaggerated body language. The other individual is walking behind, facing away from the camera, which gives them a profile view. There are no signs of conflict or fighting. It seems like a casual, recreational beach scene with a humorous caption suggesting the person on the right might be trying to get the attention of a lifeguard (jokingly referred to as "you are monitoring a beach safety camera"). The overall atmosphere appears light-hearted and fun.
#
# --- Analyzing video at second 1 ---

# %%
import cv2
import ollama
import time

# 2. Clean file path: Notice the 'r' at the start and only ONE set of quotes!
video_path = r"C:\beach\data\raw\beach\fighting\Surfers fight on the beach #fight #viral #surfer #mma #streetfighter [JDcSBEGGpXg].mp4"

# Open the video using OpenCV
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file. Check if the path is 100% correct.")
else:
    # Get the frame rate (FPS) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video loaded successfully. FPS: {fps}")

    frame_count = 0
    analyses_done = 0

    print("Starting video analysis. Processing 1 frame per second (Max 3 frames for this test)...")

    while cap.isOpened() and analyses_done < 3:
        ret, frame = cap.read()
        
        if not ret:
            print("End of video reached.")
            break
            
        # Process 1 frame every second
        if frame_count % int(fps) == 0:
            print(f"\n--- Analyzing video at second {analyses_done} ---")
            
            # Convert the OpenCV frame (numpy array) into JPG image bytes for LLaVA
            _, buffer = cv2.imencode('.jpg', frame)
            image_bytes = buffer.tobytes()
            
            # Send the extracted frame to LLaVA
            response = ollama.generate(
                model='llava:13b',
                prompt='You are monitoring a beach safety camera. Briefly describe the scene. Is anyone fighting?',
                images=[image_bytes]
            )
            
            print(f"LLaVA: {response['response']}")
            analyses_done += 1
            
        frame_count += 1

    # Clean up
    cap.release()
    print("\nVideo test complete!")
# Out:
# Video loaded successfully. FPS: 30.0
# Starting video analysis. Processing 1 frame per second (Max 3 frames for this test)...
#
# --- Analyzing video at second 0 ---
# LLaVA:  The image shows two individuals on a sandy beach, both holding surfboards and wearing wetsuits that suggest they have been or intend to surf. They appear to be engaged in a conversation with one another rather than being involved in any aggressive activity. There is no visible evidence of fighting or conflict. The focus of their interaction seems casual and social, which would not typically trigger the monitoring of a beach safety camera.
#
# --- Analyzing video at second 1 ---
# LLaVA:  In the image, there is a person on a sandy beach carrying a surfboard under their arm, heading towards the sea. There's another individual in the background who appears to be walking away from the camera. The scene seems peaceful without any signs of physical conflict or fighting. It's a typical beach setting with clear skies and calm waters suitable for surfing activities.
#
# --- Analyzing video at second 2 ---
# LLaVA:  The image shows a person on a sandy beach with waves visible in the background. The individual appears to be carrying a surfboard, suggesting they are either heading into or coming out of the water for a surfing session. There is no indication of a fight occurring; it looks like a typical beach scene.
#
# Video test complete!
