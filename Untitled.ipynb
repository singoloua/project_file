# %%
import torch
import cv2
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt

print("PyTorch:", torch.__version__)
print("OpenCV:", cv2.__version__)
print("NumPy:", np.__version__)

# Test YOLOv8 loads
model = YOLO('yolov8n.pt')  # downloads a small model ~6MB
print("✅ YOLOv8 ready!")
print("✅ All libraries working - environment setup complete!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\singo\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PyTorch: 2.10.0+cpu
# OpenCV: 4.13.0
# NumPy: 2.2.6
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 491.5KB/s 13.0s.0s<0.2s0.5s
# ✅ YOLOv8 ready!
# ✅ All libraries working - environment setup complete!
