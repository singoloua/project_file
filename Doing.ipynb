# %% [markdown]
# ## Date: 01/03/2026
#
# #### 1. Check Python is installed:
# python --version
#
# #### 3. Create your project virtual environment:
# python -m venv beach_safety_env
#
# #### 4. Activate it:
# beach_safety_env\Scripts\activate
#
# #### 5. Install everything:
# pip install ultralytics opencv-python gradio jupyter numpy pandas matplotlib Pillow deep-sort-realtime

# %% [markdown]
# #### 6. Launch Jupyter:
# jupyter notebook

# %% [markdown]
# # -----------------

# %% [markdown]
# Do this right now in PowerShell:
# Step 1 — Go to C: drive root:
# cd C:\
#
# Step 2 — Create a short folder:
# mkdir beach
#
# Step 3 — Go into it:
# cd beach
#
# Step 4 — Create virtual environment:
# python -m venv env
#
# Step 5 — Activate it:
# env\Scripts\activate
# You should see (env) appear on the left.
#
# Step 6 — Now install:
# pip install ultralytics

# %% [markdown]
# Jupyter:
# pip install jupyter
#
# Gradio (for your chatbot UI):
# pip install gradio
